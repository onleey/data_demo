# %% [markdown]
# <a href="https://colab.research.google.com/github/onleey/data_demo/blob/master/500_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Tutorial - 파이썬으로 데이터 시각화 하기
#
# https://wikidocs.net/book/5011

# %% [markdown]
# ### 데이터 시각화
# - 데이터 시각화의 중요성을 강조하고자 할때 영국의 통계학자 프랭크 엔스컴이 만든 앤스컴 콰르텟(앤스컴 콰르텟:Ansombe's quartet)으로 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 함정을 보여주기 위한 그래프이다.
# - 앤 스컴 콰르텟 은 4 개의 데이터 셋 으로 구성 되며 각 데이터 셋 에는 2 개의 연속 변수 가 있 습니다 . 4 개 데이터 셋 은 평균 , 분산 , 상관 관계 , 회귀선 이 모두 같다 . 따라서 기술 통계 만 보면마치 같은 데이터 셋 처럼 보일 수 있다 . 하지만 이를 시각화 하면 4 가지 모두 경향 이 다르다는 사실 을 직관적 으로 알 수 있다 . 이런 점 에서 시각화 는 데이터 분석 에서 아주 중요한요소 라고 할 수 있다 .

# %%
import seaborn as sns
anscombe = sns.load_dataset('anscombe')
print(type(anscombe))
print(anscombe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# ...

# %%
import matplotlib.pyplot as plt
dataset_1 = anscombe[anscombe['dataset']=='I']
plt.plot(dataset_1['x'],dataset_1['y'])
plt.show()

# %%
import matplotlib.pyplot as plt
dataset_1 = anscombe[anscombe['dataset']=='I']

# 선이아닌 점으로 그래프를 그리려면 알파벳 소문자 'o'를 설정 한다.
plt.plot(dataset_1['x'],dataset_1['y'],'o')
plt.show()

# %%
anscombe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB

# %%
anscombe.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
anscombe['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
dataset_1 =anscombe[anscombe['dataset'] =='I']
#print(dataset_1)
dataset_2 =anscombe[anscombe['dataset'] =='II']
#print(dataset_2)
dataset_3 =anscombe[anscombe['dataset'] =='III']
#print(dataset_3)
dataset_4 =anscombe[anscombe['dataset'] =='IV']
print(dataset_4)
# Out:
#    dataset     x      y
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
print(dataset_1.describe())
print(dataset_2.describe())
print(dataset_3.describe())
print(dataset_4.describe())
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# ...

# %%
print(dir(dataset_1))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmu
# ...

# %%
# 연산을 하기 위해서 숫자 데이터만 가져온다.
# 연산을 할때 숫자가 아닌 값이 포함되어 있으면 아래와 같은 경고가 발생한다.
#FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated.

dataset_1 = dataset_1[['x','y']]
dataset_2 = dataset_2[['x','y']]
dataset_3 = dataset_3[['x','y']]
dataset_4 = dataset_4[['x','y']]

print(dataset_1)
print(dataset_2)
print(dataset_3)
print(dataset_4)
# Out:
#        x      y
# 0   10.0   8.04
# 1    8.0   6.95
# 2   13.0   7.58
# 3    9.0   8.81
# 4   11.0   8.33
# 5   14.0   9.96
# 6    6.0   7.24
# 7    4.0   4.26
# 8   12.0  10.84
# 9    7.0   4.82
# 10   5.0   5.68
#        x     y
# 11  10.0  9.14
# 12   8.0  8.14
# 13  13.0  8.74
# 14   9.0  8.77
# 15  11.0  9.26
# 16  14.0  8.10
# 17   6.0  6.13
# 18   4.0  3.10
# 19  12.0  9.13
# 20   7.0  7.26
# 21   5.0  4.74
#        x      y
# 22  10.0   7.46
# 23   8.0   6.77
# 24  13.0  12.74
# 25   9.0   7.11
# 26  11.0   7.81
# 27  14.0   8.84
# 28   6.0   6.08
# 29   4.0   5.39
# 30  12.0   8.15
# 31   7.0   6.42
# 32   5.0   5.73
#        x      y
# 33   8.0   6.58
# 34   8.0   5.76
# 35   8.0   7.71
# 36   8.0   8.84
# 37   8.0   8.47
# 38   8.0   7.04
# 39   8.0   5.25
# 40  19.0  12.50
# 41   8.0   5.56
# 42   8.0   7.91
# 43   8.0   6.89

# %%
#분산(variance)
print(dataset_1.var())
print(dataset_2.var())
print(dataset_3.var())
print(dataset_4.var())
# Out:
# x    11.000000
# y     4.127269
# dtype: float64
# x    11.000000
# y     4.127629
# dtype: float64
# x    11.00000
# y     4.12262
# dtype: float64
# x    11.000000
# y     4.123249
# dtype: float64

# %%
#공분산 (Covariance)
print(dataset_1.cov())
print(dataset_2.cov())
print(dataset_3.cov())
print(dataset_4.cov())
# Out:
#         x         y
# x  11.000  5.501000
# y   5.501  4.127269
#       x         y
# x  11.0  5.500000
# y   5.5  4.127629
#         x        y
# x  11.000  5.49700
# y   5.497  4.12262
#         x         y
# x  11.000  5.499000
# y   5.499  4.123249

# %%
#상관계수 (Correlation Coefficient)
print(dataset_1.corr())
print(dataset_2.corr())
print(dataset_3.corr())
print(dataset_4.corr())
# Out:
#           x         y
# x  1.000000  0.816421
# y  0.816421  1.000000
#           x         y
# x  1.000000  0.816237
# y  0.816237  1.000000
#           x         y
# x  1.000000  0.816287
# y  0.816287  1.000000
#           x         y
# x  1.000000  0.816521
# y  0.816521  1.000000

# %%
fig = plt.figure()

#fig.add_subplot(전체 행개수, 전체 열개수, 그래프 순서)

axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)


dataset_1 =anscombe[anscombe['dataset'] =='I']
dataset_2 =anscombe[anscombe['dataset'] =='II']
dataset_3 =anscombe[anscombe['dataset'] =='III']
dataset_4 =anscombe[anscombe['dataset'] =='IV']


axes1.plot(dataset_1['x'],dataset_1['y'],'o')
axes2.plot(dataset_2['x'],dataset_2['y'],'o')
axes3.plot(dataset_3['x'],dataset_3['y'],'o')
axes4.plot(dataset_4['x'],dataset_4['y'],'o')

#r각각의 그래프마다 제목표시
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

# 기본틀에 제목표시
fig.suptitle('Anscombe data')

# 그래프의 이름과 숫자가 겹ㅊ쳤을때 각 그래프의 레이아웃을 조절해 준다
fig.tight_layout()




plt.show()

# %% [markdown]
# ***
# 1. 평균 , 분삭, 상관계수가 같아도 그래프의 형태는 다를 수 있다.
# 2. 앤스콤 4분할 그래프는 데이터 분석시 수치에만 의존하면 잘못된 판단을 할 수 있다는 것을 알려주는 좋은 예이다.
#
# ***
